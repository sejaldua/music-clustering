# %%
import sys
import spotipy
import pprint
import yaml
import spotipy.util as util
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# %% [markdown]
# ## Spotipy Credentials and API Calls

# %%
# Get Spotipy credentials from config
def load_config():
    stream = open('config.yaml')
    user_config = yaml.load(stream, Loader=yaml.FullLoader)
    return user_config

user_config = load_config()

# %%
# Initialize Spotify API token
token = util.prompt_for_user_token(user_config['username'], scope='user-read-recently-played', client_id=user_config['client_id'], client_secret=user_config['client_secret'], redirect_uri=user_config['redirect_uri'])
sp = spotipy.Spotify(auth=token)

# %%
# A function to extract track names and URIs from a playlist
def get_playlist_info(username, playlist_uri):
    # initialize vars
    offset = 0
    tracks, uris, names, artists = [], [], [], []

    # get playlist id and name from URI
    playlist_id = playlist_uri.split(':')[2]
    playlist_name = sp.user_playlist(username, playlist_id)['name']

    # get all tracks in given playlist (max limit is 100 at a time --> use offset)
    while True:
        results = sp.user_playlist_tracks(username, playlist_id, offset=offset)
        tracks += results['items']
        if results['next'] is not None:
            offset += 100
        else:
            break
        
    # get track metadata
    for track in tracks:
        names.append(track['track']['name'])
        artists.append(track['track']['artists'][0]['name'])
        uris.append(track['track']['uri'])
    
    return playlist_name, names, artists, uris

# %%
# Extract features from each track in a playlist
def get_features_for_playlist(df, username, uri):
  
    # get all track metadata from given playlist
    playlist_name, names, artists, uris = get_playlist_info(username, uri)
    
    # iterate through each track to get audio features and save data into dataframe
    for name, artist, track_uri in zip(names, artists, uris):
        # print(json.dumps(track_uri, indent=4))              
        # ^ DEBUG STATEMENT ^
        
        # access audio features for given track URI via spotipy 
        audio_features = sp.audio_features(track_uri)

        # get relevant audio features
        feature_subset = [audio_features[0][col] for col in df.columns if col not in ["name", "artist", "track_URI", "playlist"]]

        # compose a row of the dataframe by flattening the list of audio features
        row = [name, artist, track_uri, *feature_subset, playlist_name]
        df.loc[len(df.index)] = row
    return df

# %%
df = pd.DataFrame(columns=['name', 'artist', 'track_URI', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'playlist'])

# %%
df = get_features_for_playlist(df, user_config['username'], 'spotify:playlist:3VZCYCHOtahASqlkxE8vJx')
df
# Out:
#                                                   name           artist  \
# 0                                       Way With Words          Bahamas
# 1                                             Caroline  Briston Maroney
# 2                                      Hear Me Calling       Juice WRLD
# 3                                           94 Bentley        SAINt JHN
# 4                             I Feel Like I'm Drowning         Two Feet
# ..                                                 ...              ...
# 444  Lay Your Head On Me (feat. Marcus Mumford) - J...      Major Lazer
# 445                                 Damn (feat. 6lack)         Omah Lay
# 446                                              Bubba      Jack Larsen
# 447                                       Perfect Blue     Elle Valenci
# 448                                          Good Days              SZA
#
#                                 track_URI  acousticness  danceability  energy  \
# 0    spotify:track:6ioeN8jQ8Qc3tS8dhpoAVi       0.35900         0.785   0.530
# 1    spotify:track:3S5mohVxC0Xuj0tgZ7vU7g       0.72600         0.506   0.456
# 2    spotify:track:13ZyrkCDmRz5xY3seuAWYk       0.30800         0.699   0.687
# 3    spotify:track:0xxbDtdmc88FOV7YvpEtft       0.07920         0.696   0.558
# 4    spotify:track:5h0ODSutX73Vt4vZsmmph0       0.70500         0.719   0.575
# ..                                    ...           ...           ...     ...
# 444  spotify:track:29v0kvBmnIurnEn34I2haX       0.00398         0.679   0.778
# 445  spotify:track:2SVObssPWzeJquNyR05NjL       0.32700         0.590   0.434
# 446  spotify:track:0qOe0oNsO7459dYDAlomiV       0.53300         0.285   0.539
# 447  spotify:track:0u834tjHl0zB9xdPO5KrQX       0.89500         0.540   0.273
# 448  spotify:track:3YJJjQPAbDT7mGpX3WtQ9A       0.22600         0.456   0.784
#
#      instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0            0.001980    0.0774    -6.995       0.0634  146.380   0.7290
# 1            0.000037    0.1100   -10.635       0.0479  149.600   0.4060
# 2            0.000036    0.1210    -3.997       0.1060   88.932   0.4990
# 3            0.000000    0.1620    -5.253       0.0512  113.000   0.2170
# 4            0.003340    0.0899    -5.436       0.0460  104.894   0.2350
# ..                ...       ...       ...          ...      ...      ...
# 444          0.449000    0.2500    -6.063       0.0354  126.002   0.8760
# 445          0.000000    0.1020    -5.975       0.2530  141.392   0.4930
# 446          0.003420    0.0995    -8.305       0.0273  170.007   0.0466
# 447          0.002230    0.1010   -12.123       0.0918   70.875   0.2860
# 448          0.000079    0.7170    -6.289       0.0592  121.199   0.5250
#
#     playlist
# 0     twenty
# 1     twenty
# 2     twenty
# 3     twenty
# 4     twenty
# ..       ...
# 444   twenty
# 445   twenty
# 446   twenty
# 447   twenty
# 448   twenty
#
# [449 rows x 13 columns]

# %%
sp.current_user_recently_played()
# Out:
# {'items': [{'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6UcJxoeHWWWyT5HZP064om'},
#        'href': 'https://api.spotify.com/v1/artists/6UcJxoeHWWWyT5HZP064om',
#        'id': '6UcJxoeHWWWyT5HZP064om',
#        'name': 'Chet Faker',
#        'type': 'artist',
#        'uri': 'spotify:artist:6UcJxoeHWWWyT5HZP064om'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ipoWTaBfknOP3YgEXW4oY'},
#      'href': 'https://api.spotify.com/v1/albums/5ipoWTaBfknOP3YgEXW4oY',
#      'id': '5ipoWTaBfknOP3YgEXW4oY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734da1e75803f1d7e50c9aebbe',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024da1e75803f1d7e50c9aebbe',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514da1e75803f1d7e50c9aebbe',
#        'width': 64}],
#      'name': 'Low',
#      'release_date': '2020-10-02',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5ipoWTaBfknOP3YgEXW4oY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6UcJxoeHWWWyT5HZP064om'},
#       'href': 'https://api.spotify.com/v1/artists/6UcJxoeHWWWyT5HZP064om',
#       'id': '6UcJxoeHWWWyT5HZP064om',
#       'name': 'Chet Faker',
#       'type': 'artist',
#       'uri': 'spotify:artist:6UcJxoeHWWWyT5HZP064om'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 274423,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUOXM2000278'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/52AlJfHPhlkY7OGrb2AjeQ'},
#     'href': 'https://api.spotify.com/v1/tracks/52AlJfHPhlkY7OGrb2AjeQ',
#     'id': '52AlJfHPhlkY7OGrb2AjeQ',
#     'is_local': False,
#     'name': 'Low',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a98a927ab51d6f171bdf663fc9bf332425d99221?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:52AlJfHPhlkY7OGrb2AjeQ'},
#    'played_at': '2020-12-30T20:53:02.118Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EOdr5kZsNdWao'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EOdr5kZsNdWao',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EOdr5kZsNdWao'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6igfLpd8s6DBBAuwebRUuo'},
#        'href': 'https://api.spotify.com/v1/artists/6igfLpd8s6DBBAuwebRUuo',
#        'id': '6igfLpd8s6DBBAuwebRUuo',
#        'name': 'Josh Ritter',
#        'type': 'artist',
#        'uri': 'spotify:artist:6igfLpd8s6DBBAuwebRUuo'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7fxtWEwKKrFaykKItspdYg'},
#        'href': 'https://api.spotify.com/v1/artists/7fxtWEwKKrFaykKItspdYg',
#        'id': '7fxtWEwKKrFaykKItspdYg',
#        'name': 'The Milk Carton Kids',
#        'type': 'artist',
#        'uri': 'spotify:artist:7fxtWEwKKrFaykKItspdYg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/62i2sayoTnaamWkZjgtdyY'},
#      'href': 'https://api.spotify.com/v1/albums/62i2sayoTnaamWkZjgtdyY',
#      'id': '62i2sayoTnaamWkZjgtdyY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a8798e88038d6b318fe1449a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a8798e88038d6b318fe1449a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a8798e88038d6b318fe1449a',
#        'width': 64}],
#      'name': 'Losing Battles (Acoustic)',
#      'release_date': '2020-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:62i2sayoTnaamWkZjgtdyY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6igfLpd8s6DBBAuwebRUuo'},
#       'href': 'https://api.spotify.com/v1/artists/6igfLpd8s6DBBAuwebRUuo',
#       'id': '6igfLpd8s6DBBAuwebRUuo',
#       'name': 'Josh Ritter',
#       'type': 'artist',
#       'uri': 'spotify:artist:6igfLpd8s6DBBAuwebRUuo'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7fxtWEwKKrFaykKItspdYg'},
#       'href': 'https://api.spotify.com/v1/artists/7fxtWEwKKrFaykKItspdYg',
#       'id': '7fxtWEwKKrFaykKItspdYg',
#       'name': 'The Milk Carton Kids',
#       'type': 'artist',
#       'uri': 'spotify:artist:7fxtWEwKKrFaykKItspdYg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 308037,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMFBM1900011'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4vSkrhpwJ6krXg1oaZAaz9'},
#     'href': 'https://api.spotify.com/v1/tracks/4vSkrhpwJ6krXg1oaZAaz9',
#     'id': '4vSkrhpwJ6krXg1oaZAaz9',
#     'is_local': False,
#     'name': 'Losing Battles - Acoustic',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4cd5b8c33e617143321eb3e3d4a0463f9b9c43c5?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4vSkrhpwJ6krXg1oaZAaz9'},
#    'played_at': '2020-12-30T19:59:12.099Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EOdr5kZsNdWao'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EOdr5kZsNdWao',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EOdr5kZsNdWao'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Z3IWpvwOvoaWodujHw7xh'},
#        'href': 'https://api.spotify.com/v1/artists/5Z3IWpvwOvoaWodujHw7xh',
#        'id': '5Z3IWpvwOvoaWodujHw7xh',
#        'name': 'Dan Deacon',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Z3IWpvwOvoaWodujHw7xh'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/10e9Nf6QFZMTEy5TQm8G85'},
#      'href': 'https://api.spotify.com/v1/albums/10e9Nf6QFZMTEy5TQm8G85',
#      'id': '10e9Nf6QFZMTEy5TQm8G85',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273df6f9e0ed734405af4ffc44a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02df6f9e0ed734405af4ffc44a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851df6f9e0ed734405af4ffc44a',
#        'width': 64}],
#      'name': 'Mystic Familiar',
#      'release_date': '2020-01-31',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:10e9Nf6QFZMTEy5TQm8G85'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Z3IWpvwOvoaWodujHw7xh'},
#       'href': 'https://api.spotify.com/v1/artists/5Z3IWpvwOvoaWodujHw7xh',
#       'id': '5Z3IWpvwOvoaWodujHw7xh',
#       'name': 'Dan Deacon',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Z3IWpvwOvoaWodujHw7xh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 245414,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL1900374'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1NIjx6oS7ECM5UtTpPUFIa'},
#     'href': 'https://api.spotify.com/v1/tracks/1NIjx6oS7ECM5UtTpPUFIa',
#     'id': '1NIjx6oS7ECM5UtTpPUFIa',
#     'is_local': False,
#     'name': 'Become a Mountain',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/31f46db2033185fe21ca88b071ece2679a811e2a?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1NIjx6oS7ECM5UtTpPUFIa'},
#    'played_at': '2020-12-30T19:54:04.419Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EOdr5kZsNdWao'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EOdr5kZsNdWao',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EOdr5kZsNdWao'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1nhSLEYdoBHG6cJ8NDwoF1'},
#        'href': 'https://api.spotify.com/v1/artists/1nhSLEYdoBHG6cJ8NDwoF1',
#        'id': '1nhSLEYdoBHG6cJ8NDwoF1',
#        'name': 'Fickle Friends',
#        'type': 'artist',
#        'uri': 'spotify:artist:1nhSLEYdoBHG6cJ8NDwoF1'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7qR1HoEKO0Rb4jRhoFlBip'},
#      'href': 'https://api.spotify.com/v1/albums/7qR1HoEKO0Rb4jRhoFlBip',
#      'id': '7qR1HoEKO0Rb4jRhoFlBip',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bce392c087a24908b83d20c9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bce392c087a24908b83d20c9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bce392c087a24908b83d20c9',
#        'width': 64}],
#      'name': 'Pretty Great',
#      'release_date': '2020-01-17',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:7qR1HoEKO0Rb4jRhoFlBip'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1nhSLEYdoBHG6cJ8NDwoF1'},
#       'href': 'https://api.spotify.com/v1/artists/1nhSLEYdoBHG6cJ8NDwoF1',
#       'id': '1nhSLEYdoBHG6cJ8NDwoF1',
#       'name': 'Fickle Friends',
#       'type': 'artist',
#       'uri': 'spotify:artist:1nhSLEYdoBHG6cJ8NDwoF1'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 213053,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBCEJ1900357'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5OEh0t74eilX1HnfVy9E4g'},
#     'href': 'https://api.spotify.com/v1/tracks/5OEh0t74eilX1HnfVy9E4g',
#     'id': '5OEh0t74eilX1HnfVy9E4g',
#     'is_local': False,
#     'name': 'Pretty Great',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/aee3583e100adfaebfc736bb6ee13479177d4343?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5OEh0t74eilX1HnfVy9E4g'},
#    'played_at': '2020-12-30T19:49:58.741Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EOdr5kZsNdWao'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EOdr5kZsNdWao',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EOdr5kZsNdWao'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Qi9Fcmn1DJAoG8Agf5ibb'},
#        'href': 'https://api.spotify.com/v1/artists/0Qi9Fcmn1DJAoG8Agf5ibb',
#        'id': '0Qi9Fcmn1DJAoG8Agf5ibb',
#        'name': 'Bonny Light Horseman',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Qi9Fcmn1DJAoG8Agf5ibb'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5OgTkrQuF1aL0FtsTi5KmV'},
#      'href': 'https://api.spotify.com/v1/albums/5OgTkrQuF1aL0FtsTi5KmV',
#      'id': '5OgTkrQuF1aL0FtsTi5KmV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27365229c854ebcf1009616ded3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0265229c854ebcf1009616ded3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485165229c854ebcf1009616ded3',
#        'width': 64}],
#      'name': 'Bonny Light Horseman',
#      'release_date': '2020-01-24',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5OgTkrQuF1aL0FtsTi5KmV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Qi9Fcmn1DJAoG8Agf5ibb'},
#       'href': 'https://api.spotify.com/v1/artists/0Qi9Fcmn1DJAoG8Agf5ibb',
#       'id': '0Qi9Fcmn1DJAoG8Agf5ibb',
#       'name': 'Bonny Light Horseman',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Qi9Fcmn1DJAoG8Agf5ibb'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LBdlNpHBD8dHPcVCrjSB6'},
#       'href': 'https://api.spotify.com/v1/artists/4LBdlNpHBD8dHPcVCrjSB6',
#       'id': '4LBdlNpHBD8dHPcVCrjSB6',
#       'name': 'Eric D. Johnson',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LBdlNpHBD8dHPcVCrjSB6'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3kKgcBXTgyAZhXPV3AaSZc'},
#       'href': 'https://api.spotify.com/v1/artists/3kKgcBXTgyAZhXPV3AaSZc',
#       'id': '3kKgcBXTgyAZhXPV3AaSZc',
#       'name': 'Josh Kaufman',
#       'type': 'artist',
#       'uri': 'spotify:artist:3kKgcBXTgyAZhXPV3AaSZc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7K5Lm5dxoEwEpOS0Fc3l3s'},
#       'href': 'https://api.spotify.com/v1/artists/7K5Lm5dxoEwEpOS0Fc3l3s',
#       'id': '7K5Lm5dxoEwEpOS0Fc3l3s',
#       'name': 'Anaïs Mitchell',
#       'type': 'artist',
#       'uri': 'spotify:artist:7K5Lm5dxoEwEpOS0Fc3l3s'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 260832,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMB621900803'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/17lBx44cu6JhILH7ifq6sI'},
#     'href': 'https://api.spotify.com/v1/tracks/17lBx44cu6JhILH7ifq6sI',
#     'id': '17lBx44cu6JhILH7ifq6sI',
#     'is_local': False,
#     'name': 'The Roving',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3ac190e5410e9328cf037e7b284c2f089d8f4e36?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:17lBx44cu6JhILH7ifq6sI'},
#    'played_at': '2020-12-30T19:46:25.629Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EOdr5kZsNdWao'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EOdr5kZsNdWao',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EOdr5kZsNdWao'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0RDC2Krd2nmqseGx5C8PQz'},
#        'href': 'https://api.spotify.com/v1/artists/0RDC2Krd2nmqseGx5C8PQz',
#        'id': '0RDC2Krd2nmqseGx5C8PQz',
#        'name': 'Kllo',
#        'type': 'artist',
#        'uri': 'spotify:artist:0RDC2Krd2nmqseGx5C8PQz'}],
#      'available_markets': ['CA',
#       'CR',
#       'DO',
#       'GT',
#       'HN',
#       'MX',
#       'NI',
#       'PA',
#       'SV',
#       'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6XjkpRegoBsPzuJnyZDZ5W'},
#      'href': 'https://api.spotify.com/v1/albums/6XjkpRegoBsPzuJnyZDZ5W',
#      'id': '6XjkpRegoBsPzuJnyZDZ5W',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273164535601cefd4edb7d52f6c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02164535601cefd4edb7d52f6c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851164535601cefd4edb7d52f6c',
#        'width': 64}],
#      'name': 'Maybe We Could',
#      'release_date': '2020-07-17',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6XjkpRegoBsPzuJnyZDZ5W'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0RDC2Krd2nmqseGx5C8PQz'},
#       'href': 'https://api.spotify.com/v1/artists/0RDC2Krd2nmqseGx5C8PQz',
#       'id': '0RDC2Krd2nmqseGx5C8PQz',
#       'name': 'Kllo',
#       'type': 'artist',
#       'uri': 'spotify:artist:0RDC2Krd2nmqseGx5C8PQz'}],
#     'available_markets': ['CA',
#      'CR',
#      'DO',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'SV',
#      'US'],
#     'disc_number': 1,
#     'duration_ms': 214681,
#     'explicit': False,
#     'external_ids': {'isrc': 'US2J72006702'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7I0hnTwFoLMiYbdxFGiQiM'},
#     'href': 'https://api.spotify.com/v1/tracks/7I0hnTwFoLMiYbdxFGiQiM',
#     'id': '7I0hnTwFoLMiYbdxFGiQiM',
#     'is_local': False,
#     'name': 'Still Here',
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/94aa0229700861005e623316e27de308893cb4df?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7I0hnTwFoLMiYbdxFGiQiM'},
#    'played_at': '2020-12-30T19:42:04.898Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EOdr5kZsNdWao'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EOdr5kZsNdWao',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EOdr5kZsNdWao'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4qKpLkR911SUlnd4HAtF79'},
#        'href': 'https://api.spotify.com/v1/artists/4qKpLkR911SUlnd4HAtF79',
#        'id': '4qKpLkR911SUlnd4HAtF79',
#        'name': 'Nathaniel Rateliff',
#        'type': 'artist',
#        'uri': 'spotify:artist:4qKpLkR911SUlnd4HAtF79'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2bWrnSJNyGevb1pr2VYEGW'},
#      'href': 'https://api.spotify.com/v1/albums/2bWrnSJNyGevb1pr2VYEGW',
#      'id': '2bWrnSJNyGevb1pr2VYEGW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d916311911cb0c5020182a0b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d916311911cb0c5020182a0b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d916311911cb0c5020182a0b',
#        'width': 64}],
#      'name': 'And It’s Still Alright',
#      'release_date': '2020-02-14',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:2bWrnSJNyGevb1pr2VYEGW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4qKpLkR911SUlnd4HAtF79'},
#       'href': 'https://api.spotify.com/v1/artists/4qKpLkR911SUlnd4HAtF79',
#       'id': '4qKpLkR911SUlnd4HAtF79',
#       'name': 'Nathaniel Rateliff',
#       'type': 'artist',
#       'uri': 'spotify:artist:4qKpLkR911SUlnd4HAtF79'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 235746,
#     'explicit': False,
#     'external_ids': {'isrc': 'USC4R1907159'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2tRxHjEkdgGMv9kZbOyqOH'},
#     'href': 'https://api.spotify.com/v1/tracks/2tRxHjEkdgGMv9kZbOyqOH',
#     'id': '2tRxHjEkdgGMv9kZbOyqOH',
#     'is_local': False,
#     'name': "And It's Still Alright",
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/897c30b3a41e4fa1b11f4f92ebf21c1330135778?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2tRxHjEkdgGMv9kZbOyqOH'},
#    'played_at': '2020-12-30T19:38:30.226Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EOdr5kZsNdWao'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EOdr5kZsNdWao',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EOdr5kZsNdWao'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1oghnjbVNJIYKnNhV3Y5cR'},
#        'href': 'https://api.spotify.com/v1/artists/1oghnjbVNJIYKnNhV3Y5cR',
#        'id': '1oghnjbVNJIYKnNhV3Y5cR',
#        'name': 'The George Kaplan Conspiracy',
#        'type': 'artist',
#        'uri': 'spotify:artist:1oghnjbVNJIYKnNhV3Y5cR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7zKNyfOAofayv8jZj4Jlcn'},
#      'href': 'https://api.spotify.com/v1/albums/7zKNyfOAofayv8jZj4Jlcn',
#      'id': '7zKNyfOAofayv8jZj4Jlcn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27378192bb42403d216a923f84d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0278192bb42403d216a923f84d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485178192bb42403d216a923f84d',
#        'width': 64}],
#      'name': 'Recollected Memories',
#      'release_date': '2019-04-05',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:7zKNyfOAofayv8jZj4Jlcn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1oghnjbVNJIYKnNhV3Y5cR'},
#       'href': 'https://api.spotify.com/v1/artists/1oghnjbVNJIYKnNhV3Y5cR',
#       'id': '1oghnjbVNJIYKnNhV3Y5cR',
#       'name': 'The George Kaplan Conspiracy',
#       'type': 'artist',
#       'uri': 'spotify:artist:1oghnjbVNJIYKnNhV3Y5cR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 244522,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRU451600093'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3VdTkrOXjoKe4nutykkoz1'},
#     'href': 'https://api.spotify.com/v1/tracks/3VdTkrOXjoKe4nutykkoz1',
#     'id': '3VdTkrOXjoKe4nutykkoz1',
#     'is_local': False,
#     'name': 'Again',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8ec3839784a004dfceded42b1a61709d29088764?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:3VdTkrOXjoKe4nutykkoz1'},
#    'played_at': '2020-12-30T19:34:12.148Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/7iAkkvQ11nmfS1Rv1N5YYr'},
#     'href': 'https://api.spotify.com/v1/playlists/7iAkkvQ11nmfS1Rv1N5YYr',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7iAkkvQ11nmfS1Rv1N5YYr'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#        'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#        'id': '5cj0lLjcoR7YOSnhnX0Po5',
#        'name': 'Doja Cat',
#        'type': 'artist',
#        'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3jCcsG6jkQTnUJyCACAg0r'},
#      'href': 'https://api.spotify.com/v1/albums/3jCcsG6jkQTnUJyCACAg0r',
#      'id': '3jCcsG6jkQTnUJyCACAg0r',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27363a175ab64de0b0ada98700e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0263a175ab64de0b0ada98700e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485163a175ab64de0b0ada98700e',
#        'width': 64}],
#      'name': 'Freak',
#      'release_date': '2020-08-07',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3jCcsG6jkQTnUJyCACAg0r'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#       'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#       'id': '5cj0lLjcoR7YOSnhnX0Po5',
#       'name': 'Doja Cat',
#       'type': 'artist',
#       'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 284480,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC12002580'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3aA6xB0tOilDDX17fIJ0Bl'},
#     'href': 'https://api.spotify.com/v1/tracks/3aA6xB0tOilDDX17fIJ0Bl',
#     'id': '3aA6xB0tOilDDX17fIJ0Bl',
#     'is_local': False,
#     'name': 'Freak',
#     'popularity': 78,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f285f3ab917331d4f566bd00a47d749958d5fac3?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3aA6xB0tOilDDX17fIJ0Bl'},
#    'played_at': '2020-12-30T19:30:07.563Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/7iAkkvQ11nmfS1Rv1N5YYr'},
#     'href': 'https://api.spotify.com/v1/playlists/7iAkkvQ11nmfS1Rv1N5YYr',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7iAkkvQ11nmfS1Rv1N5YYr'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Z3IWpvwOvoaWodujHw7xh'},
#        'href': 'https://api.spotify.com/v1/artists/5Z3IWpvwOvoaWodujHw7xh',
#        'id': '5Z3IWpvwOvoaWodujHw7xh',
#        'name': 'Dan Deacon',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Z3IWpvwOvoaWodujHw7xh'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/10e9Nf6QFZMTEy5TQm8G85'},
#      'href': 'https://api.spotify.com/v1/albums/10e9Nf6QFZMTEy5TQm8G85',
#      'id': '10e9Nf6QFZMTEy5TQm8G85',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273df6f9e0ed734405af4ffc44a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02df6f9e0ed734405af4ffc44a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851df6f9e0ed734405af4ffc44a',
#        'width': 64}],
#      'name': 'Mystic Familiar',
#      'release_date': '2020-01-31',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:10e9Nf6QFZMTEy5TQm8G85'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Z3IWpvwOvoaWodujHw7xh'},
#       'href': 'https://api.spotify.com/v1/artists/5Z3IWpvwOvoaWodujHw7xh',
#       'id': '5Z3IWpvwOvoaWodujHw7xh',
#       'name': 'Dan Deacon',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Z3IWpvwOvoaWodujHw7xh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 245414,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEL1900374'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1NIjx6oS7ECM5UtTpPUFIa'},
#     'href': 'https://api.spotify.com/v1/tracks/1NIjx6oS7ECM5UtTpPUFIa',
#     'id': '1NIjx6oS7ECM5UtTpPUFIa',
#     'is_local': False,
#     'name': 'Become a Mountain',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/31f46db2033185fe21ca88b071ece2679a811e2a?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1NIjx6oS7ECM5UtTpPUFIa'},
#    'played_at': '2020-12-30T19:25:23.180Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/7iAkkvQ11nmfS1Rv1N5YYr'},
#     'href': 'https://api.spotify.com/v1/playlists/7iAkkvQ11nmfS1Rv1N5YYr',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7iAkkvQ11nmfS1Rv1N5YYr'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3d13oWvwmjcodRr3NzdArc'},
#        'href': 'https://api.spotify.com/v1/artists/3d13oWvwmjcodRr3NzdArc',
#        'id': '3d13oWvwmjcodRr3NzdArc',
#        'name': 'Forester',
#        'type': 'artist',
#        'uri': 'spotify:artist:3d13oWvwmjcodRr3NzdArc'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7fUGG2D7Z3cLm3YYNeUPqJ'},
#      'href': 'https://api.spotify.com/v1/albums/7fUGG2D7Z3cLm3YYNeUPqJ',
#      'id': '7fUGG2D7Z3cLm3YYNeUPqJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27399090ade994445f62c537c8d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0299090ade994445f62c537c8d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485199090ade994445f62c537c8d',
#        'width': 64}],
#      'name': 'Kerosene',
#      'release_date': '2019-09-06',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:7fUGG2D7Z3cLm3YYNeUPqJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3d13oWvwmjcodRr3NzdArc'},
#       'href': 'https://api.spotify.com/v1/artists/3d13oWvwmjcodRr3NzdArc',
#       'id': '3d13oWvwmjcodRr3NzdArc',
#       'name': 'Forester',
# ...
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 329653,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDUW0700002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4IdiGMOzEYXOh2897XOV8i'},
#     'href': 'https://api.spotify.com/v1/tracks/4IdiGMOzEYXOh2897XOV8i',
#     'id': '4IdiGMOzEYXOh2897XOV8i',
#     'is_local': False,
#     'name': 'Touch It / Technologic',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/71c958b90ea51e487f842e132236008c5986ef9e?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4IdiGMOzEYXOh2897XOV8i'},
#    'played_at': '2020-12-29T07:29:47.538Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/1wSwbl8OSSIqorQp6hlWTh'},
#     'href': 'https://api.spotify.com/v1/playlists/1wSwbl8OSSIqorQp6hlWTh',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1wSwbl8OSSIqorQp6hlWTh'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KjAo6wVc9d2WcxdxSArpV'},
#        'href': 'https://api.spotify.com/v1/artists/2KjAo6wVc9d2WcxdxSArpV',
#        'id': '2KjAo6wVc9d2WcxdxSArpV',
#        'name': 'RY X',
#        'type': 'artist',
#        'uri': 'spotify:artist:2KjAo6wVc9d2WcxdxSArpV'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7E3BRXV9ZbCt5lQTCXMTia'},
#        'href': 'https://api.spotify.com/v1/artists/7E3BRXV9ZbCt5lQTCXMTia',
#        'id': '7E3BRXV9ZbCt5lQTCXMTia',
#        'name': 'Ólafur Arnalds',
#        'type': 'artist',
#        'uri': 'spotify:artist:7E3BRXV9ZbCt5lQTCXMTia'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6kfKntjGEwjKUL7q43j5rO'},
#      'href': 'https://api.spotify.com/v1/albums/6kfKntjGEwjKUL7q43j5rO',
#      'id': '6kfKntjGEwjKUL7q43j5rO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bf06f195f7a27fae2272d28e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bf06f195f7a27fae2272d28e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bf06f195f7a27fae2272d28e',
#        'width': 64}],
#      'name': 'Oceans',
#      'release_date': '2020-01-31',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6kfKntjGEwjKUL7q43j5rO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KjAo6wVc9d2WcxdxSArpV'},
#       'href': 'https://api.spotify.com/v1/artists/2KjAo6wVc9d2WcxdxSArpV',
#       'id': '2KjAo6wVc9d2WcxdxSArpV',
#       'name': 'RY X',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KjAo6wVc9d2WcxdxSArpV'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7E3BRXV9ZbCt5lQTCXMTia'},
#       'href': 'https://api.spotify.com/v1/artists/7E3BRXV9ZbCt5lQTCXMTia',
#       'id': '7E3BRXV9ZbCt5lQTCXMTia',
#       'name': 'Ólafur Arnalds',
#       'type': 'artist',
#       'uri': 'spotify:artist:7E3BRXV9ZbCt5lQTCXMTia'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 279573,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBBC1900179'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2eVofaQRJvddSUBfcub7Gz'},
#     'href': 'https://api.spotify.com/v1/tracks/2eVofaQRJvddSUBfcub7Gz',
#     'id': '2eVofaQRJvddSUBfcub7Gz',
#     'is_local': False,
#     'name': 'Oceans',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/07d428da1001e190747fe3c99c553616eb560074?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2eVofaQRJvddSUBfcub7Gz'},
#    'played_at': '2020-12-29T07:24:17.368Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/1wSwbl8OSSIqorQp6hlWTh'},
#     'href': 'https://api.spotify.com/v1/playlists/1wSwbl8OSSIqorQp6hlWTh',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1wSwbl8OSSIqorQp6hlWTh'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7sOR7gk6XUlGnxj3p9F54k'},
#        'href': 'https://api.spotify.com/v1/artists/7sOR7gk6XUlGnxj3p9F54k',
#        'id': '7sOR7gk6XUlGnxj3p9F54k',
#        'name': 'half•alive',
#        'type': 'artist',
#        'uri': 'spotify:artist:7sOR7gk6XUlGnxj3p9F54k'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BL8zABAvKYgRFjwsQIjwa'},
#      'href': 'https://api.spotify.com/v1/albums/0BL8zABAvKYgRFjwsQIjwa',
#      'id': '0BL8zABAvKYgRFjwsQIjwa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27347188c9ed18ac386f8ead3d4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0247188c9ed18ac386f8ead3d4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485147188c9ed18ac386f8ead3d4',
#        'width': 64}],
#      'name': 'in Florescence',
#      'release_date': '2020-05-01',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:0BL8zABAvKYgRFjwsQIjwa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7sOR7gk6XUlGnxj3p9F54k'},
#       'href': 'https://api.spotify.com/v1/artists/7sOR7gk6XUlGnxj3p9F54k',
#       'id': '7sOR7gk6XUlGnxj3p9F54k',
#       'name': 'half•alive',
#       'type': 'artist',
#       'uri': 'spotify:artist:7sOR7gk6XUlGnxj3p9F54k'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 229480,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC12001162'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5ClQJdS0GnURmm8xZpG4OD'},
#     'href': 'https://api.spotify.com/v1/tracks/5ClQJdS0GnURmm8xZpG4OD',
#     'id': '5ClQJdS0GnURmm8xZpG4OD',
#     'is_local': False,
#     'name': 'RUNAWAY - w/ Orchestra',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8bb199f14c8d07fb9608e7a98742c962db15ca51?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5ClQJdS0GnURmm8xZpG4OD'},
#    'played_at': '2020-12-29T07:19:37.260Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/1wSwbl8OSSIqorQp6hlWTh'},
#     'href': 'https://api.spotify.com/v1/playlists/1wSwbl8OSSIqorQp6hlWTh',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1wSwbl8OSSIqorQp6hlWTh'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0P3oVJBFOv3TDXlYRhGL7s'},
#      'href': 'https://api.spotify.com/v1/albums/0P3oVJBFOv3TDXlYRhGL7s',
#      'id': '0P3oVJBFOv3TDXlYRhGL7s',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737fcead687e99583072cc217b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027fcead687e99583072cc217b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517fcead687e99583072cc217b',
#        'width': 64}],
#      'name': 'Beauty Behind The Madness',
#      'release_date': '2015-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0P3oVJBFOv3TDXlYRhGL7s'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2feDdbD5araYcm6JhFHHw7'},
#       'href': 'https://api.spotify.com/v1/artists/2feDdbD5araYcm6JhFHHw7',
#       'id': '2feDdbD5araYcm6JhFHHw7',
#       'name': 'Labrinth',
#       'type': 'artist',
#       'uri': 'spotify:artist:2feDdbD5araYcm6JhFHHw7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 281146,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG11500915'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1bAvtmTl0F9loyz9AwPwp7'},
#     'href': 'https://api.spotify.com/v1/tracks/1bAvtmTl0F9loyz9AwPwp7',
#     'id': '1bAvtmTl0F9loyz9AwPwp7',
#     'is_local': False,
#     'name': 'Losers',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8a3b52e83cd4875a60dab040d1caf8d15f8bdf16?cid=596a6d95b0904fdfa3988f5c7752dd55',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1bAvtmTl0F9loyz9AwPwp7'},
#    'played_at': '2020-12-29T07:15:47.329Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/1wSwbl8OSSIqorQp6hlWTh'},
#     'href': 'https://api.spotify.com/v1/playlists/1wSwbl8OSSIqorQp6hlWTh',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1wSwbl8OSSIqorQp6hlWTh'}}],
#  'next': 'https://api.spotify.com/v1/me/player/recently-played?before=1609226147329&limit=50',
#  'cursors': {'after': '1609361582118', 'before': '1609226147329'},
#  'limit': 50,
#  'href': 'https://api.spotify.com/v1/me/player/recently-played?limit=50'}

# %%
sp.trace = True
user = sp.current_user()
pprint.pprint(user)
# Out:
# {'display_name': 'Sejal Dua',
#  'external_urls': {'spotify': 'https://open.spotify.com/user/srrzaa61gi4hzx02avrosh1n9'},
#  'followers': {'href': None, 'total': 24},
#  'href': 'https://api.spotify.com/v1/users/srrzaa61gi4hzx02avrosh1n9',
#  'id': 'srrzaa61gi4hzx02avrosh1n9',
#  'images': [{'height': None,
#              'url': 'https://i.scdn.co/image/ab6775700000ee85d34ef02977f41b325d7e54d3',
#              'width': None}],
#  'type': 'user',
#  'uri': 'spotify:user:srrzaa61gi4hzx02avrosh1n9'}
